# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumarthaduri/AIML_BATCH_10/blob/main/Lab01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## LAb activity on Numpy,Pandas,Matplotlib

# %% [markdown]
# # **Lab activity-01 on Numpy,Pandas and MatplotLib**

# %%
import numpy as np
list1=[1,2,3,]
array1=np.array(list1)
print(array1)
# Out:
# [1 2 3]

# %%
type(list1)
type(array1)
# Out:
# numpy.ndarray

# %% [markdown]
# ## **Perform Mathematical Operation - Multiply,Subtract,Power of**

# %%
list2=[3,2,1]
array2=np.array(list2)
array2*array1
print("Multiplication of Array1 and Array2 gives:",array2*array1)
# Out:
# Multiplication of Array1 and Array2 gives: [3 4 3]

# %%
#sine function
print("Sine:",np.sin(array1))
#logarithm
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
#Exponential
print("Exponential: ",np.exp(array1))
# Out:
# Sine: [0.84147098 0.90929743 0.14112001]
# Natural logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithm:  [0.        1.        1.5849625]
# Exponential:  [ 2.71828183  7.3890561  20.08553692]

# %% [markdown]
# # **Exe-01 scatterplot-basic**

# %%
people=['Annie','Brian','Charlie','Damon']
age=[21,12,32,45]
weight=[55,35,77,68]
height=[160,130,170,165]
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.show()

# %% [markdown]
# ## **Bar Chart**

# %%
plt.figure(figsize=(12,14))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# # **Histograph**

# %%
import numpy as np
plt.figure(figsize=(7,5))
#main plot function 'hist'
plt.hist(weight,color='orange',edgecolor='k',alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
